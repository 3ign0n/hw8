# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("TRAIN.csv")

# %%
sns.pairplot(df)
# Out:
# /usr/local/var/pyenv/versions/3.7.0/envs/ml_env/lib/python3.7/site-packages/numpy/lib/histograms.py:746: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/var/pyenv/versions/3.7.0/envs/ml_env/lib/python3.7/site-packages/numpy/lib/histograms.py:747: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
